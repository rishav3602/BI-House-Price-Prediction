# %%
import pandas as pd

# %%
## Data Ingestion step
data = pd.read_csv('data/test.csv')
data
# Out:
#          Area  BHK  Bathroom      Furnishing  \
# 0       800.0    3       2.0  Semi-Furnished
# 1       750.0    2       2.0  Semi-Furnished
# 2       950.0    2       2.0       Furnished
# 3       600.0    2       2.0  Semi-Furnished
# 4       650.0    2       2.0  Semi-Furnished
# ...       ...  ...       ...             ...
# 1254   4118.0    4       5.0     Unfurnished
# 1255   1050.0    3       2.0  Semi-Furnished
# 1256    875.0    3       3.0  Semi-Furnished
# 1257    990.0    2       2.0     Unfurnished
# 1258  11050.0    3       3.0     Unfurnished
#
#                                                Locality  Parking     Price  \
# 0                                      Rohini Sector 25      1.0   6500000
# 1                J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                   Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                      Rohini Sector 24      1.0   4200000
# ...

# %%
df = data.copy()
df.head()
# Out:
#     Area  BHK  Bathroom      Furnishing  \
# 0  800.0    3       2.0  Semi-Furnished
# 1  750.0    2       2.0  Semi-Furnished
# 2  950.0    2       2.0       Furnished
# 3  600.0    2       2.0  Semi-Furnished
# 4  650.0    2       2.0  Semi-Furnished
#
#                                             Locality  Parking     Price  \
# 0                                   Rohini Sector 25      1.0   6500000
# 1             J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                   Rohini Sector 24      1.0   4200000
# 4  Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
#
#           Status   Transaction           Type  Per_Sqft
# 0  Ready_to_move  New_Property  Builder_Floor       NaN
# 1  Ready_to_move  New_Property      Apartment    6667.0
# 2  Ready_to_move        Resale      Apartment    6667.0
# 3  Ready_to_move        Resale  Builder_Floor    6667.0
# ...

# %%
df.columns
# Out:
# Index(['Area', 'BHK', 'Bathroom', 'Furnishing', 'Locality', 'Parking', 'Price',
#        'Status', 'Transaction', 'Type', 'Per_Sqft'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area         1259 non-null   float64
#  1   BHK          1259 non-null   int64
#  2   Bathroom     1257 non-null   float64
#  3   Furnishing   1254 non-null   object
#  4   Locality     1259 non-null   object
#  5   Parking      1226 non-null   float64
#  6   Price        1259 non-null   int64
#  7   Status       1259 non-null   object
#  8   Transaction  1259 non-null   object
#  9   Type         1254 non-null   object
#  10  Per_Sqft     1018 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 108.3+ KB

# %%
df.head()
# Out:
#     Area  BHK  Bathroom      Furnishing  \
# 0  800.0    3       2.0  Semi-Furnished
# 1  750.0    2       2.0  Semi-Furnished
# 2  950.0    2       2.0       Furnished
# 3  600.0    2       2.0  Semi-Furnished
# 4  650.0    2       2.0  Semi-Furnished
#
#                                             Locality  Parking     Price  \
# 0                                   Rohini Sector 25      1.0   6500000
# 1             J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                   Rohini Sector 24      1.0   4200000
# 4  Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
#
#           Status   Transaction           Type  Per_Sqft
# 0  Ready_to_move  New_Property  Builder_Floor       NaN
# 1  Ready_to_move  New_Property      Apartment    6667.0
# 2  Ready_to_move        Resale      Apartment    6667.0
# 3  Ready_to_move        Resale  Builder_Floor    6667.0
# ...

# %%
df.describe()
# Out:
#                Area          BHK     Bathroom      Parking         Price  \
# count   1259.000000  1259.000000  1257.000000  1226.000000  1.259000e+03
# mean    1466.452724     2.796664     2.556086     1.935563  2.130670e+07
# std     1568.055040     0.954425     1.042220     6.279212  2.560115e+07
# min       28.000000     1.000000     1.000000     1.000000  1.000000e+06
# 25%      800.000000     2.000000     2.000000     1.000000  5.700000e+06
# 50%     1200.000000     3.000000     2.000000     1.000000  1.420000e+07
# 75%     1700.000000     3.000000     3.000000     2.000000  2.550000e+07
# max    24300.000000    10.000000     7.000000   114.000000  2.400000e+08
#
#             Per_Sqft
# count    1018.000000
# mean    15690.136542
# std     21134.738568
# min      1259.000000
# 25%      6364.000000
# 50%     11291.500000
# 75%     18000.000000
# max    183333.000000

# %%
df.shape
# Out:
# (1259, 11)

# %%
df.head(5)
# Out:
#     Area  BHK  Bathroom      Furnishing  \
# 0  800.0    3       2.0  Semi-Furnished
# 1  750.0    2       2.0  Semi-Furnished
# 2  950.0    2       2.0       Furnished
# 3  600.0    2       2.0  Semi-Furnished
# 4  650.0    2       2.0  Semi-Furnished
#
#                                             Locality  Parking     Price  \
# 0                                   Rohini Sector 25      1.0   6500000
# 1             J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                   Rohini Sector 24      1.0   4200000
# 4  Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
#
#           Status   Transaction           Type  Per_Sqft
# 0  Ready_to_move  New_Property  Builder_Floor       NaN
# 1  Ready_to_move  New_Property      Apartment    6667.0
# 2  Ready_to_move        Resale      Apartment    6667.0
# 3  Ready_to_move        Resale  Builder_Floor    6667.0
# ...

# %%
# we will check for the null values
df.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         2
# Furnishing       5
# Locality         0
# Parking         33
# Price            0
# Status           0
# Transaction      0
# Type             5
# Per_Sqft       241
# dtype: int64

# %%
df[df.Bathroom.isnull()]
# Out:
#        Area  BHK  Bathroom   Furnishing        Locality  Parking     Price  \
# 30   1500.0    1       NaN  Unfurnished  Lajpat Nagar 2      NaN  13500000
# 120  1500.0    1       NaN  Unfurnished  Lajpat Nagar 2      NaN  13500000
#
#             Status Transaction       Type  Per_Sqft
# 30   Ready_to_move      Resale  Apartment       NaN
# 120  Ready_to_move      Resale  Apartment       NaN

# %%
df = df.drop(labels=[30,120],axis=0)

# %%
#we have just 2 data in bathroom column so we deleted that.
df.shape
df.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         0
# Furnishing       5
# Locality         0
# Parking         31
# Price            0
# Status           0
# Transaction      0
# Type             5
# Per_Sqft       239
# dtype: int64

# %%
len(df[df.Bathroom.isnull()])
# Out:
# 0

# %%
df[df.Furnishing.isnull()]
# Out:
#        Area  BHK  Bathroom Furnishing  \
# 509   450.0    2       2.0        NaN
# 510   540.0    5       2.0        NaN
# 511  1350.0    3       3.0        NaN
# 512  2250.0    3       2.0        NaN
# 719  1500.0    3       2.0        NaN
#
#                                               Locality  Parking     Price  \
# 509                             Gandhi Nagar, Shahdara      NaN   2900000
# 510                             Gandhi Nagar, Shahdara      NaN  17000000
# 511                             Gandhi Nagar, Shahdara      NaN  25000000
# 512                             Gandhi Nagar, Shahdara      NaN  10000000
# 719  Sarita Vihar, Mathura Road carpet area 1500 sq...      1.0  13500000
#
#             Status Transaction Type  Per_Sqft
# 509  Ready_to_move      Resale  NaN   58000.0
# 510  Ready_to_move      Resale  NaN   58000.0
# 511  Ready_to_move      Resale  NaN   18519.0
# 512  Ready_to_move      Resale  NaN    4444.0
# 719  Ready_to_move      Resale  NaN       NaN

# %%
df = df.drop(labels=[509,510,511,512,719],axis=0)

# %%
len(df[df.Furnishing.isnull()])
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         0
# Furnishing       0
# Locality         0
# Parking         27
# Price            0
# Status           0
# Transaction      0
# Type             0
# Per_Sqft       238
# dtype: int64

# %%
df[df.Parking.isnull()]
# Out:
#         Area  BHK  Bathroom      Furnishing  \
# 90     900.0    1       1.0  Semi-Furnished
# 269   2799.0    4       4.0  Semi-Furnished
# 299    700.0    2       2.0     Unfurnished
# 300    750.0    2       2.0  Semi-Furnished
# 513   1250.0    2       1.0  Semi-Furnished
# 514    504.0    3       1.0  Semi-Furnished
# 515     65.0    3       2.0  Semi-Furnished
# 516    450.0    2       1.0     Unfurnished
# 517   1800.0    4       2.0       Furnished
# 518   1800.0    4       3.0       Furnished
# 519   1530.0    5       2.0       Furnished
# 569   1800.0    3       3.0  Semi-Furnished
# 599   1620.0    3       3.0  Semi-Furnished
# 659   3050.0    5       6.0  Semi-Furnished
# 689    700.0    2       2.0     Unfurnished
# 779    950.0    3       2.0  Semi-Furnished
# 809    650.0    2       2.0  Semi-Furnished
# 810    405.0    1       1.0  Semi-Furnished
# 811    675.0    2       1.0     Unfurnished
# 899    750.0    2       2.0     Unfurnished
# ...

# %%
#dropping the parking, status and Type column cause it is of less use.
df=df.drop(labels=['Parking','Locality','Type'],axis=1)

# %%
df.columns
# Out:
# Index(['Area', 'BHK', 'Bathroom', 'Furnishing', 'Price', 'Status',
#        'Transaction', 'Per_Sqft'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         0
# Furnishing       0
# Price            0
# Status           0
# Transaction      0
# Per_Sqft       238
# dtype: int64

# %%
## There is few null values in Per_Sqft 
## Now we will have to fill these null values
df['Per_Sqft'] = df['Per_Sqft'].fillna(df['Per_Sqft'].median())
df.head()
# Out:
#     Area  BHK  Bathroom      Furnishing     Price         Status  \
# 0  800.0    3       2.0  Semi-Furnished   6500000  Ready_to_move
# 1  750.0    2       2.0  Semi-Furnished   5000000  Ready_to_move
# 2  950.0    2       2.0       Furnished  15500000  Ready_to_move
# 3  600.0    2       2.0  Semi-Furnished   4200000  Ready_to_move
# 4  650.0    2       2.0  Semi-Furnished   6200000  Ready_to_move
#
#     Transaction  Per_Sqft
# 0  New_Property   11165.5
# 1  New_Property    6667.0
# 2        Resale    6667.0
# 3        Resale    6667.0
# 4  New_Property    6667.0

# %%
len(df[df.Per_Sqft.isnull()])
# Out:
# 0

# %%
df.isnull().sum()
#we do not have any null values now we are good to go.
# Out:
# Area           0
# BHK            0
# Bathroom       0
# Furnishing     0
# Price          0
# Status         0
# Transaction    0
# Per_Sqft       0
# dtype: int64

# %%
## checking for the duplicated data
df[df.duplicated()]
# Out:
#         Area  BHK  Bathroom      Furnishing     Price         Status  \
# 84    1540.0    3       3.0  Semi-Furnished  14500000  Ready_to_move
# 92    1450.0    3       3.0  Semi-Furnished  30000000  Ready_to_move
# 93    1260.0    3       3.0  Semi-Furnished  21000000  Ready_to_move
# 110   1000.0    2       2.0       Furnished  20000000  Ready_to_move
# 122   1710.0    3       3.0  Semi-Furnished  26000000  Ready_to_move
# ...      ...  ...       ...             ...       ...            ...
# 1164  1300.0    2       2.0  Semi-Furnished  15000000  Ready_to_move
# 1165  1200.0    2       2.0     Unfurnished  14300000  Ready_to_move
# 1166  1300.0    3       2.0     Unfurnished  18500000  Ready_to_move
# 1167  1400.0    3       3.0       Furnished  19000000  Ready_to_move
# 1168  1400.0    3       3.0  Semi-Furnished  19000000  Ready_to_move
#
#        Transaction  Per_Sqft
# 84          Resale    3524.0
# 92    New_Property   11165.5
# 93          Resale   11165.5
# ...

# %%
df
# Out:
#          Area  BHK  Bathroom      Furnishing     Price         Status  \
# 0       800.0    3       2.0  Semi-Furnished   6500000  Ready_to_move
# 1       750.0    2       2.0  Semi-Furnished   5000000  Ready_to_move
# 2       950.0    2       2.0       Furnished  15500000  Ready_to_move
# 3       600.0    2       2.0  Semi-Furnished   4200000  Ready_to_move
# 4       650.0    2       2.0  Semi-Furnished   6200000  Ready_to_move
# ...       ...  ...       ...             ...       ...            ...
# 1254   4118.0    4       5.0     Unfurnished  55000000  Ready_to_move
# 1255   1050.0    3       2.0  Semi-Furnished  12500000  Ready_to_move
# 1256    875.0    3       3.0  Semi-Furnished  17500000  Ready_to_move
# 1257    990.0    2       2.0     Unfurnished  11500000  Ready_to_move
# 1258  11050.0    3       3.0     Unfurnished  18500000  Ready_to_move
#
#        Transaction  Per_Sqft
# 0     New_Property   11165.5
# 1     New_Property    6667.0
# 2           Resale    6667.0
# ...

# %%
## segregate numerical and categorical columns

numerical_columns=df.columns[df.dtypes!='object']
categorical_columns=df.columns[df.dtypes=='object']
print("Numerical columns:",numerical_columns)
print('Categorical Columns:',categorical_columns)
# Out:
# Numerical columns: Index(['Area', 'BHK', 'Bathroom', 'Price', 'Per_Sqft'], dtype='object')
# Categorical Columns: Index(['Furnishing', 'Status', 'Transaction'], dtype='object')

# %%
df[categorical_columns].describe()
# Out:
#             Furnishing         Status Transaction
# count             1252           1252        1252
# unique               3              2           2
# top     Semi-Furnished  Ready_to_move      Resale
# freq               708           1177         774

# %%
df['Furnishing'].value_counts()
# Out:
# Semi-Furnished    708
# Unfurnished       361
# Furnished         183
# Name: Furnishing, dtype: int64

# %%
df['Status'].value_counts()
# Out:
# Ready_to_move    1177
# Almost_ready       75
# Name: Status, dtype: int64

# %%
df['Transaction'].value_counts()
# Out:
# Resale          774
# New_Property    478
# Name: Transaction, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
x=0
for i in numerical_columns:
    sns.histplot(data=df,x=i,kde=True)
    print('\n')
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
x=0
for i in categorical_columns:
    sns.histplot(data=df,x=i,kde=True)
    print('\n')
    plt.show()

# %%
## correlation
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# here we can see that we have very less corelation

# %%
df[categorical_columns]
# Out:
#           Furnishing         Status   Transaction
# 0     Semi-Furnished  Ready_to_move  New_Property
# 1     Semi-Furnished  Ready_to_move  New_Property
# 2          Furnished  Ready_to_move        Resale
# 3     Semi-Furnished  Ready_to_move        Resale
# 4     Semi-Furnished  Ready_to_move  New_Property
# ...              ...            ...           ...
# 1254     Unfurnished  Ready_to_move  New_Property
# 1255  Semi-Furnished  Ready_to_move        Resale
# 1256  Semi-Furnished  Ready_to_move  New_Property
# 1257     Unfurnished  Ready_to_move        Resale
# 1258     Unfurnished  Ready_to_move  New_Property
#
# [1252 rows x 3 columns]

# %%
## we are mapping all the categorical features

# %%
df['Furnishing'].unique()
# Out:
# array(['Semi-Furnished', 'Furnished', 'Unfurnished'], dtype=object)

# %%
Furnishing_map={"Unfurnished":1,"Semi-Furnished":2,"Furnished":3}

# %%
df['Status'].unique()
# Out:
# array(['Ready_to_move', 'Almost_ready'], dtype=object)

# %%
Status_map={"Almost_ready":1,"Ready_to_move":2}

# %%
df['Transaction'].unique()
# Out:
# array(['New_Property', 'Resale'], dtype=object)

# %%
Transaction_map= {"Resale":1,"New_Property":2}

# %%
df['Furnishing']=df['Furnishing'].map(Furnishing_map)
df['Status'] = df['Status'].map(Status_map)
df['Transaction'] = df['Transaction'].map(Transaction_map)

# %%
df.head()
# Out:
#     Area  BHK  Bathroom  Furnishing     Price  Status  Transaction  Per_Sqft
# 0  800.0    3       2.0           2   6500000       2            2   11165.5
# 1  750.0    2       2.0           2   5000000       2            2    6667.0
# 2  950.0    2       2.0           3  15500000       2            1    6667.0
# 3  600.0    2       2.0           2   4200000       2            1    6667.0
# 4  650.0    2       2.0           2   6200000       2            2    6667.0
